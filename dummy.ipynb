# %%
from pathlib import Path
import glob
import os 

TRAIN_PATH = Path(os.getcwd() + "/train-data")
glob.glob(str(TRAIN_PATH / "ben") + "*.pdf")
# Out:
# []

# %%
TRAIN_PATH = Path(os.getcwd() + "/train-data")
TRAIN_PATH
# Out:
# PosixPath('/Users/tmittra/doc-language-identification/train-data')

# %%
str(TRAIN_PATH / "ben")
# Out:
# '/Users/tmittra/doc-language-identification/train-data/ben'

# %%
# !ls -lrt /Users/tmittra/doc-language-identification/train-data/ben
# Out:
# total 4592
# -rw-r--r--@ 1 tmittra  staff   758597 10 Apr 17:04 book1.pdf
# -rw-r--r--@ 1 tmittra  staff  1587682 10 Apr 17:05 book2.pdf

# %%
import os 

os.listdir(str(TRAIN_PATH / "ben"))
# Out:
# ['book1.pdf', 'book2.pdf']

# %%
glob.glob(str(TRAIN_PATH / "ben") + "/*.pdf")
# Out:
# ['/Users/tmittra/doc-language-identification/train-data/ben/book1.pdf',
#  '/Users/tmittra/doc-language-identification/train-data/ben/book2.pdf']
